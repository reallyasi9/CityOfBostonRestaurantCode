# %% [markdown]
# Play with reviews data and try clustering reviews

# %%
import pandas as pd, numpy as np, os, nltk, langdetect, datetime as dt
import joblib as jb
import multiprocessing

from nltk.corpus import stopwords
stopwords = stopwords.words('english') # replace the stop word list

import string
punctuations = set(string.punctuation)

# %% [markdown]
# Import business id to yelp id crosswalk

# %%
id_map = pd.read_csv("data/restaurant_ids_to_yelp_ids.csv")
id_dict = {}

# each Yelp ID may correspond to up to 4 Boston IDs
for i, row in id_map.iterrows():
    # get the Boston ID
    boston_id = row["restaurant_id"]
    
    # get the non-null Yelp IDs
    non_null_mask = ~pd.isnull(row.ix[1:])
    yelp_ids = row[1:][non_null_mask].values
    
    for yelp_id in yelp_ids:
        id_dict[yelp_id] = boston_id

# %% [markdown]
# Read in yelp reviews

# %%
with open("data/yelp_academic_dataset_review.json", 'r') as review_file:
    # the file is not actually valid json since each line is an individual
    # dict -- we will add brackets on the very beginning and ending in order
    # to make this an array of dicts and join the array entries with commas
    review_json = '[' + ','.join(review_file.readlines()) + ']'

# read in the json as a DataFrame
reviews = pd.read_json(review_json)

# drop columns that we won't use
reviews.drop(['review_id', 'type', 'user_id', 'votes'], 
             inplace=True, 
             axis=1)

# replace yelp business_id with boston restaurant_id
map_to_boston_ids = lambda yelp_id: id_dict[yelp_id] if yelp_id in id_dict else np.nan
reviews.business_id = reviews.business_id.map(map_to_boston_ids)

# rename first column to restaurant_id so we can join with boston data
reviews.columns = ["restaurant_id", "date", "stars", "text"]    

# drop restaurants not found in boston data
reviews = reviews[pd.notnull(reviews.restaurant_id)]

reviews.head()
# Out:
#   restaurant_id       date  stars  \
# 0      N6Ok7qOx 2005-08-26      3
# 1      N6Ok7qOx 2005-11-23      3
# 2      N6Ok7qOx 2005-11-23      3
# 3      N6Ok7qOx 2006-02-24      5
# 4      N6Ok7qOx 2007-09-06      3
#
#                                                 text
# 0  This is a pretty typical cafe.  The sandwiches...
# 1  I agree with other reviewers - this is a prett...
# 2  Decent enough food, but very overpriced. Just ...
# 3  The muffins are great...esp the blueberry!  I ...
# 4  Well, well, well, look at me reviewing the res...

# %% [markdown]
# Use langdetect to detect languages. The apply below is slow. Played around with multiprocessing and it has about 2x the speed over 10000k records. Couldnt implement on iPython Notebook though. Works when running on terminal. This step takes 42 minutes on Francos laptop

# %%
def detect(string):
    try:
        return langdetect.detect(string)
    except:
        return "langdetect failed"

start = dt.datetime.now()
col = reviews['text']
col2 = col.apply(detect)
print "Duration: ", dt.datetime.now() - start
# Out:
# Duration:  0:43:01.456000

# %% [markdown]
# Store results

# %%
reviews['language'] = col2
reviews.to_pickle('data/intermediate/langdetect.pkl')

# %% [markdown]
# Present the text that langdetect had an error with:

# %%
reviews = pd.read_pickle('data/intermediate/langdetect.pkl')
reviews.loc[reviews['language'] == "langdetect failed","text"]
# Out:
# 38035                                                  ....
# 60779            http://www.youtube.com/watch?v=h-ElqPW2ZSE
# 62814     :):):):):):)):):):):)):):):):):)):):)::)::):);...
# 70798                                                   ???
# 85961                                                     .
# 113890                                                    .
# 115926                                               :'(~~~
# 128110                                                    *
# 152445                                                  ...
# 191269                                               .\n...
# 192039                                                   :)
# 193817                                                   :)
# 194054                                                    .
# 224698                                                    .
# 227400                                                    .
# Name: text, dtype: object

# %% [markdown]
# Also present frequency of languages:

# %%
by = reviews.groupby(['language'])
by['language'].agg(len)
# Out:
# language
# af                       58
# ca                       24
# cs                        2
# cy                       24
# da                       26
# de                       73
# en                   228068
# es                       56
# et                       11
# fi                        4
# fr                       72
# hr                        5
# hu                        2
# id                       15
# it                       94
# ja                       12
# ko                        6
# langdetect failed        15
# lv                        1
# nl                       42
# no                       32
# pl                        6
# pt                       15
# ro                       34
# sk                        2
# sl                       12
# so                       34
# sq                        6
# sv                        7
# sw                       11
# tl                       15
# tr                       14
# zh-cn                     6
# zh-tw                     1
# Name: language, dtype: int64

# %% [markdown]
# Present the text for languages that are not english.

# %%
for i, row in (reviews.loc[reviews['language'] != 'en',['language','text']]).iterrows():
    print row['language'], ":", row['text']
# Out:
# cy : Pretty damn good!
# de : best manwiches ever!
# de : HUGE sandwiches.  Amazing.
# it : Below average pizza place..
# da : Great after work drinks ... Worst Reuben I have ever eaten ! Horrible !
# et : just....bad.
# sq : I like Pete the Pizzamaker.
# tr : Yuck!
# ca : Excellent bar!
# es : Buenísima ubicación ! Pieza un poco pequeña
# fr : Bon pratique, prix corrects, terrasse. Bon pour un déjeuner rapide ou à toute heure.
#
# Mais on n'est pas chez Fairmont Bagel, rien à voir en qualité.
# nl : Best beef in Boston.
# sw : amazing
# de : Do it.
# ro : Spectacular Spectacular!!!
# fr : En attendant le doublement des lieux d'exposition (nouveau corps de bâtiment en construction), profitez des lieux pour admirer les très belles pièces d'art d'Europe (Impressionnistes, post-impressionnistes, mais aussi Art Médiéval et expressionnisme allemand...), chinois, égyptien... Belles expositions temporaires à ne pas manquer, mais nécessitant souvent de prendre billets à l'avance si visite les soirs et les W/E!
# de : Ganz ehrlich: Eines der besten Museen, die ich je besucht habe. Der Eintritt ist für ein Museum dieser Art ok (ca. 25 Dollar), zumal es zumindest bei meinem Besuch im Sommer möglich war, dass man das Ticket eine ganze Woche verwenden kann  und es ist auch überhaupt nicht möglich, alle Kunstwerke an einem Tag zu bewältigen.
# Als Hilfreich habe ich die Audiotour empfunden mit interessanten Infos zu vielen Kunstwerken  allein im Raum mit den Musikinstrumenten aus diversen Epochen habe ich fast zwei Stunden verbracht.
# Hier ist wohl auch für jeden Kunstliebhaber etwas dabei  ob Skulpturen, Sarkophage, Bilder  zu allen Epochen und aus allen Regionen der Welt gibt es viel zu sehen. Soweit ich weiß, gibt es im MFA auch die größte Monet-Sammlung außerhalb Europas.
# Wer in Boston vorbeischaut, sollte einen Besuch hier auf jeden Fall einplanen!
# af : Awesome museum!
# fr : Super café... comme endroit, mais aussi comme source du breuvage...
#
# Les bostoniens ne comprennent normalement pas "espresso", "court", "serré"... c'est le seul café à Boston où ils ont compris soit :
#
# "As little water as possible", "half water" ou "condensed coffee"...
#
# Mais là aussi, il faut insister...
#
# C'est plus facile de retrouver un café au lait (latté) à Boston (au moins 3 cafés)... mais le meilleur de ceux que j'ai essayé se trouve ici. C'est d'ailleurs un pied-de-nez aux cafés "third wave" avec leur "java-art" mais un moins bon goût... :)
#
# J'ai essayé 2 types d'omelettes (#8-berkeley et #9-western) et 2 types de bagels (#1-bagel aux oeufs et #2-bagel fromage/tomate)... et j'ai été très heureux par le rappprt qualité/prix élevé...
# (Très bien fait et pas cher).
#
# Un peu déçu par lea smoothies (banane/fraise et mango tango) qui étaient un peu "farineux" (peut-être des bananes trop vertes??) ...
# no : I like it
# nl : Van buiten ziet dit restaurant er prima uit en omdat het regende ben ik snel naar binnen gegaan. Binnen zag het restaurant er mooi uit met veel kunst aan de muur en prettige inrichting. Wel zaten er maar twee andere gasten in het restaurant. Onze gastheer was ontzettend vriendelijk en enthousiast, typisch Amerikaans natuurlijk.
#
# Helaas had ik mijn yelp huiswerk niet gedaan voordat ik dit restaurant binnen liep. Toen ik met de gratis WiFi reviews las, kwamen er eigenlijk alleen maar slechte beoordelingen langs, en ja... Ik vond het ook niet al te best.
#
# Ik koos voor de 'Lobster Roll'. Ik verwachtte een heerlijke lobster met wat frietjes en groente. Helaas kreeg ik een soort langwerpig hotdog broodje met lobsterstukjes en ui erop gekwakt, veel te veel vette friet en platgeslagen sla. Echt ontzettend jammer, want het was nog best prijzig. Hier kom ik echt niet meer!!
# de : Top of the Hub ist DIE rooftop-Bar in Boston. Man erreicht sie durch das Prudential Center, welches in einem 52.stöckigen Hochaus untergebracht hat. Beim abendlichen Zutritt durch die Shoppingmal verlangt die Security i.d.R. eine Pass, dessen Daten notiert werden.
#
#
#  In der grossen Rooftopbar, die durch deckenhohe Fenster einen hervorragenden Ausblick auf Boston ermöglicht, gibt es zahlreiche Sitzplaetze direkt am Fenster, -dort erwartet das Restaurant einen Mindestverzehr von 25$ pro Person, aber auch eine lange Bar, an der kein Mindestverzehr gilt.
#
#
#  Es empfiehlt sich zu reservieren, - wer 5-15 Minuten Zeit mitbringt, bekommt aber auch oft ohne zu reservieren einen Tisch.
#
#
#  Das Essen ist der gehobenen Küche zuzuordnen, aber weder überwältigend noch viel zu teuer. Angemessen halt. Es gibt ein Dreigang-Menue zu 38$.
#
#
#  Cocktails muß man ca. 12-15$ rechnen. Bier und Wein ist übermässig teuer.
#
#
#  Der Service war schnell und freundlich.
# de : Meh
# zh-tw : 波士頓最高的餐廳，
# 不過要窗戶旁邊還是需要一點運氣，
# 不過，如果沒有被安排到窗邊，
# 還是可以走過去周圍拍攝照片。
#
# 俯瞰整看 Boston，
# 雖然當天霧濛濛的，
# 但也別有一番不一樣的風味。
#
# 印象中點了一個前菜鹹時（海鮮相關），
# 吃完非常飽足，只是前菜啊！
# 果然是用美國人的胃口來做菜
#
# 飲料方面就比較普通了，
# 沒有什麼驚艷的地方。
#
# 來到波士頓，你不能不來這邊發呆！
# no : I still have gas from my grease omelette! 2 days later.
# ja : 仕事とはいえ、Boston に来たんで、記念に食べましょうということで。
#
# おいしいか、おいしくないかといえば、まあおいしいでしょう。それに、観光気分で「あれ、食べた食べた」と後々から思い出せる、言えるという経験料もプラスすると、$18+程度はお買い得かな。
#
# お店は Quincy Market の中にあって、そこで買ったものを、中央のテーブルスペースで食べます。
#
# それ以上にあまり言うことが思いつかないあたりで、食事自体の満足感はお察しください。繰り返しますが、普通においしいです。
# ro : Rude rude rude !!!!
# nl : The best Hoegaarden in Boston is poured here.
# ja : ホテルのコンシェルジュにおすすめされたシーフード！
# ここのクラムチャウダーは塩っ気が強いけど、すごく美味しい
# すごく人気店だから忙しそうだけど、店員さんも優しいし、おすすめ！
# ja : Boston 大雪で、開いてない店も多数。正解を求めてさまようよりも、Legal seafoodなら外さないだろうとやってきました。ホテルから近かったし、開いてたし。
#
# 同僚と二人で来ましたが、まずは気分を盛り上げるために Steamers を。日本ではあまり見ないスタイルなので、喜んでました。ちょっと砂が多かったかな。でも、味は安定だし、エンターテイメントとして食べるのも楽しいし、満足です。
#
# メインは Lobster。サイドに、Mashed potato と Broccoli and Cheese を選びます。Lobster は、Small, Medium, Large から選ぶようになってます。以前（て10年ぐらい前か）Bostonの他の店で食べたときは、目方でかなり大きいものも頼めたような気がしたけど気のせいかな。何れにせよ、二人で一番大きいのを stuffed lobster にしてシェアしましたが、十分満足できました。
#
# Lobsterは、Lobster味でした(^^。Stuffedもおいしかったけど、純粋にLobsterを味わうなら、シンプルな steamed の方がいいかも。
#
# ワインは Stag's Leap Napa Valley Chardonnay が $52 ということで、普通の値段設定。おいしくのめました。
#
# ウェイトレスは感じが良かったですが、空いているのにちょっと急かしぎみだったかな。
#
# というわけで、雰囲気含め、冒険せず、安定の味とサービスを求めるなら、Legal seafoodは良い選択肢でしょう。
# da : Good lobster. You get 2 entire lobsters for $35!
# de : Ein schönes italienisch angehauchtes Restaurant in toller Lage in Boston, MA. Gut geeignet für ein Dinner mit Geschäftsfreunden aber auch für einen schönen Abend mit Freunden.
# Das Essen ist "italienisch", aber das sollte man nicht so ernst nehmen, auch eine Paella ist auf der Karte zu finden. Ich hatte Pork-Chops: Eine Riesenportion (und auch die Anderen am Tisch sind gut satt geworden).
#
#
#  Insgesamt ein durchaus positives Erlebnis, auch wenn ich jetzt (als Europäer) nicht sagen würde, dass das Restaurant italienische Spitzenklasse ist.
#
#
#  Grundsätzlich: In der Fleet Street gibt's eine Menge schöne Restaurants, die meisten versuchen sich "italienisch" zu geben. Einfach mal entlangschlendern.
# es : llegamos a este restaurante de casualidad y entramos, la comida buena, el servicio correcto pero nada especial, me pareció demasiado turístico y funcional
# sq : I like it.  I like it a lot.
# it : Boston's best pizzeria.
# it : Best Pizza boston experiance ever
# it : BEST pizza ever..and Santarpio's SUCKS!
# it : Great Pizza!!!!
# pl : Best pizza in B-town
# it : Excellent Mediterranean pizza
# es : Increíbles pizzas, largas filas, parking imposible pero cuando estas degustando semejante obra de arte todo todoooooo habrá valido la pena.
# cy : YUM YUM YUM!!!! Enough said!
# ca : Excellent!!
# it : Ham & cheese panini, cheesy and flavorful. Ricotta ham & salami, good balance of flavor, cheesy & salty. Arancini, panzaroti are all delicious
# it : Hands down favorite pizza place in Boston -- delicious Sicilian pizza
# ro : Nice
# lv : Pasta pasta pasta
# it : excellent gnocchi!
# it : my favorite pizza, period.
# it : I could get better pizza at dominoes.
# it : Huge, delicious slices of pizza.
# it : GIANT slices of amazing pizza
# it : my favorite is shrimp scampi pizza on Fridays
# cy : meh. no grimaldi's. yes i am a new york snob.
# it : Great Pizza
# it : Loved Lasagna!
# es : Squid ink pasta delicious
# de : Super Lobster!!!! Love it!
# ko : 龍蝦麵還不錯吃
# 份量非常大
# 可以兩到三人分
#
# 美中不足的是空間非常狹小 不收信用卡
# ja : Website を見ると、すごくおしゃれなお店のように見えますが、実際は、おしゃれさ、古さ、新しさ、スマートさ、ごちゃごちゃ感のまざった、バーのような、レストランのような、ハンバーガーショップのような、ファミレスのような、変なバランスの店です。
#
# North Street にある、ちょっとおしゃれなお店たちとも、なんだかちぐはぐな感じ。
#
# そんな雰囲気にあまり似合わないフレンチトーストやサンドイッチが売りの店のようでもありますが、ハンバーガーもおいしそうだったので、ハンバーガーを食べました。
#
# アメリカの、おいしいまともなハンバーガーといったところでしょうか。ノリとしては、Wheelhouse の方がおいしかったかな。
#
# 私は、Name this burger というハンバーガーを食べました。Gorgonzola, crispy fried onions, avocado という組み合わせがおいしそうなのもありますが、どっちかというと名前に魅かれてネタで食べました。名前の由来を聞いてみましたが、特にないとのこと。適当に名前つけて食べてとのこと。無責任な(^^
#
# パテの焼き加減もいい感じでありました。Quincy Market あたりの観光客向けのお店に飽きたらお試しを。
# ca : Edible.
# sw : Amazing
# af : Steak & cheese sub was Devine!
# nl : Another hidden gem of dorchester
# es : fun
# pl : wicked nice
# ro : Best fries...great prices...great pub fare.
# af : Gaawwwwwgeousssss
# af : Sub par boston diner
# de : Das Hotel liegt direkt am Prudential Center sehr zentral. Es gibt einen direkten Durchgang von diesem Gebäude aus zum Hotel. Außerdem ist die U-Bahn nur wenige Geh-Minuten entfernt.
# Das Parken in diesem Hotel ist vergleichsweise sehr teuer. 24h Valet-Parking kosten 42 US$.
# Das Personal wirkt nicht sehr ogranisiert und schnell überfordert, was sehr schade ist. Denn ansonsten ist dieses Hotel wirklich top! Frisch renoviert macht es einen netten Eindruck und auch die Zimmer sind groß und geräumig. Die Betten sind bequem und im Bad gibt es genug Platz - einzig der Ausblick auf das Nachbargebäude ist nicht so schön. Auch die Sauberkeit war nicht zufriedenstellend für ein 4-Sterne Hotel.
# Es gab keine Minibar, stattdessen einen Kühlschrank, der wohl früher mal eine Minibar war - der stinkt aber sehr, so dass wir ihn nicht genutzt haben.
# Swimming Pool ist sehr groß und sauber - genauso wie auch der Rest des Wellness- und Fitness-Bereichs.
# Alles in allem ist das Hotel empfehlenswert, wenn man über Priceline oder andere Seiten bucht. Den vollen Preis würde ich dafür aber nicht zahlen.
# es : De los mejores fast food. Lo más recomendable el Orange chicken.
# it : Great vanilla chai.
# it : Accanto all'hotel 140 c'è un negozio di Dunkin' Donuts, che stando alla pubblicità, sono le ciambelle su cui si muove l'america (America Runs on Dunkin), ma sono pericolose, perchè una tira l'altra ed il costo è bassissimo, si rischia pertanto di farsi del male prendendole a confezioni da 6 !!!
# Sapevo che il caffè americano è diverso dal nostro, molto lungo e annacquato, ma quando ho chiesto il caffè ristretto e di formato più piccolo, mi hanno dato un bicchiere che di solito uso per la birra. Sorvoliamo su questo.
# E' inutile dilungarmi perché le Dunkin' Donuts sono come i Mcdonald'S, pertanto rispettano delle logiche di omogeneità, quindi descritto uno, si riesce ad descriverli tutti.
# Si fa la fila come in posta, accettano carte di credito anche per spese di pochi dollari (siamo negli USA, è normale), vi sono i newspaper del giorno ad ogni tavolo e il personale è obeso ma gentile.
# fr : Yes.
# pl : Very tasty pizza
# af : Yep, still as good as it gets.
# da : Went for drinks after dinner. It seemed kind of old and stodgy...
# no : Smells like puke
# de : $3 PBR Drafts
# so : Good chowda.
# cy : Nom. 'nuff said
# de : Tolle Location. Gutes Essen. Manchmal lange Wartezeiten.
# fr : bonne nourriture, mais bien trop cher pour cette qualité, une attente interminable pour avoir notre table que nous avions réservé depuis 2 jours et quand nous sommes monté a l'étage, plusieurs tables étaient libre, nous n'avons pas compris pourquoi. la serveuse, efficace mais pas très aimable, aucun conseil sur les plats a prendre, le homard se vend au cours du jour et au poids, pas de Kilogrammes mais des livres (450 grammes la livre ou pound ) donc attention a l'addition.
# Apparemment, au rez de chaussée, ils servent des plats de types brasserie et en haut des plats de type restaurant.
# La boutique de souvenir est super chère.
# j'en garde un souvenir plutôt mauvais.
# fr : Habituellement, j'évite ce type de resto attrape-touristes. Mais bon pourquoi ne pas jouer le jeu cette fois-ci.
# C'est bien, mais sans plus. A vrai dire, je m'attendais à pire considérant toute la place qui est laissée au magasin de souvenirs.
# Faut essayer le clam chowder et fermer les yeux sur le kitsch de la déco à l'ancienne, mais en plastique.
# On n'y retourne pas nécessairement.
# it : Bel pub irlandese,  ci sono stato una domenica all'ora di pranzo e suonava un gruppo di irish music davvero valido, ampia scelta di birre alla spina a prezzi ottimi
# so : Slow service, total confusion , avoid until new staff figures out
#
# Xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxcxxxxxxx
# fr : Yummy Chocolate croissant
# pt : El día de ayer almorcé una langosta y realmente son de lo PEOR TE LA DAN ENTERA TU TIENES QUE LIMPIARLA TODA SON INCAPACES DE DAR UNA PRESENTACIÓN BUENA DEL PLATO Y PEDÍ QUE EN VEZ DE PAPAS FRITAS COLOCARAN OTRO CONTORNO Y LA RESPUESTA FUE NO ES SUMAMENTE MALO AL DUEÑO O SOCIOS DEL RESTAURANTE LES RECOMIENDO QUE VIAJEN AL CARIBE O A VENEZUELA PARA QUE VEAN COMO SE PREPARA UNA BUENA LANGOSTA
# fr : Le meilleur homard de ma vie.
# Idéalement situé dans le port de Boston, c'est par une journée ensoleillée et après une belle balade en bateau dans Boston Bay, que nous nous sommes arrêtés au Tia's pour déjeuner.
#
# Le housekeeping qui vient frapper à votre porte tot le matin pour faire votre chambre...mais aumoins on a eu droit à un contact humain...ca faisait du bien!
#
# Internet payant...ca faisait des lustres que ca ne m etait pas arrive!
#
# Le pire a été de trouver notre facture sous la porte juste avant notre départ...
#
# un seul truc qui fonctionnait bien: les ascenceurs!
#
# Un hôtel qui a perdu le sens du contact avec la clientèle et qui a oublié ce que le mot service signifie.
# tl : Sangria Cava!  Enough said.
# fr : Fun place for groups.
# fr : Very fun and unique atmosphere - dimly lit, can we say romantique? :)  Quiet.  Good service.
# cy : awful food, staff polite - don't go
# de : Their desserts r rich n elegant :)
# de : Mittelmäßiger Burger-Laden. Fernseher hängen überall rum und die Atmosphäre ist doch arg plastikmäßig. Dazu ein brabbelnder Kellner mit Entscheidungsbaumspeisekarten. Ziemlich überfordernd, aber im Grunde auch egal. Denn schmecken tut es nicht besonders. Frische Zutaten gibt es hier nicht und echtes Kochen ist weit weg.
# so : The Fall Salad ... sooo good.
# cy : Down and Draggy!!! Good BAD Drag goes a LONG way!
# hu : lovely.
# nl : 2 dollar 20 oz beers?
#
# Yes
#
# SIR.
# fr : Lettuce Wraps - Just do it.  DELICIOUS!
# fr : Excellent restaurant, très propre et nourriture excellente. Les portions sont généreuses, il faut donc se limiter à des entrées à deux. Bons vins à prix abordables.
# Le service était impeccable et assez rapide malgré l'affluence (août 2012) Nous n'avions pas de réservation et n'avons pas attendu plus de 5 minutes.
# Bon rapport qualité-prix.
# pt : Excelente lugar, comida saborosa, muito bom atendimento. Para quem gosta muito de massas a opção é o pacote family onde se pode experimentar entre 3 e 4 pratos e 3 petiscos da casa. Para essa opção é preciso estar no mínimo em 4 pessoas
# so : AHHH... Turkey Hash!!!
# da : Best breakfast food I have ever had.
# no : I've never had a better steak in my life.
# da : mmmm
#
#
# mmmmmm
#
#
# mmmmm
#
# just mmmm
# best venicen ever. hands down.
# so : good vibe, good food
# da : Meat market.
# af : Very good steak and potatoes.  Also had a good blueberry pie.  Good dinner.
# es : Aperitivos exquisitos. La carne de calidad y cocinada al punto exacto q se pidieron. La langosta en salsa de quesos estaba deliciosa. Es bastante caro pero la calidad es superior
# fr : Un vrai restaurant français au coeur de Back Bay. Tout est écrit en français, le menu même les toilettes! Mais personne ne parle français à part un gérant qui reste depuis plusieurs année à Boston. Choix de vin, plats succulent, plateau de fromage au dessert (choix à notre table). Mais tout cela à un prix, mais qui vaut la peine.
# af : Very tasty pie.  Very.
# de : Ein äußerst gediegenes Steakhouse in Boston.
# Gehört zur gleichnamigen, kleinen aber feinen Kette in den USA. Bereits das äussere, burgähnliche Erscheinungsbild ist vielversprechend und macht Hoffnung auf mehr.
#
#
#  Update 21.11.2010
# Wenn ich ehrlich bin wird es heute mit dem Bericht über "Dry aged Steaks" nichts. Aus einem ganz einfachen Grund. Heute waren wir mit einer "Party of 3" im Smith & Wollensky zum Dinner. Da sich alle für Filet Mignon entschieden, gab es leider für uns kein "Dry aged Steak".
#
#
#  Ich hatte auf der Hompage von Smith & Wollensky einen Tisch für 20:00 Uhr reserviert. Wie sich herausstellt, war dies kein Fehler, da der Laden ziemlich ausgebucht erschien. Mit unserer Reservierung klappte es jedoch hervorragend und wir erhielten einen Tisch in der 2ten Etage im großen Speiseraum.
# Das Interieur hier ist sehr ansprechend und wirkt gediegen. Im Raum an den Wänden verteilt, befinden sich Schränke in denen div. Weinflaschen lagern.
#
#
#  Insgesamt verteilt sich das Restaurant über mehrere Etagen ( 4 ? ) und soll ca. 450 Gästen Platz bieten. Diese Auskunft erhielt ich auf Nachfrage von einem Kellner. Von dieser Größe merkte man jedoch nichts, da sich das Restaurant auf mehreren Etagen und pro Etage auf mehrere Räume verteilt.
#
#
#  Der Service den die Kellner boten wurde von uns als nahezu perfekt empfunden.
#
#
#  Die sanitären Einrichtungen waren vorbildlich.
# af : I got steak wasted.
# de : LOD 4
#
# Lobster Roll - Good Stuff!
# fr : Hot bartender.  More on less important details later.
# no : Lobster BLT, Wellfleet oysters are my favorite!!
# ca : OYSTERS........ DROOOOOOL.... DELICIOUS. A FAN OF BL restaurants.
# af : We got
# es : Buen restaurante recomiendo los noodles.
# langdetect failed : http://www.youtube.com/watch?v=h-ElqPW2ZSE
# af : Ok. Service Ok. Food Ok. Ok.
# it : Amazing pizza. Period.
# it : Cool vibe, delicious pizza, great Caesar salad, and yummy ice cream:)
# af : Very good! I like it here... food and drink.
# fr : menu de brasserie allemande avec un très bon choix de bières et une cuisine correcte.
# Il n'y a aucune fenêtre ce que je trouve un peu déprimant mais j'ai déjà vu des brasseries semblables à Munich alors on pourrait parler de caractère authentique.
# langdetect failed : :):):):):):)):):):):)):):):):):)):):)::)::):);:):):):):):):));:)):;):))
# de : GROSS.
# af : Very good food and good drinks.
# tl : Fabulous Antipasto, Eggplant Rollatini, and Pasta
# de : Wir waren im September 2010 in Boston während einer Urlaubs-Rundreise. Nach einem anstrengenden Sightseeing-Tag quer durch die Stadt sind wir am Globe Bar & Cafe hängen geblieben, weil das Restaurant sehr schön von außen aussah und trotz seiner Lage vernünftige Preise hatte. Wir hatten Vorspeise und Hauptgang - und wir waren sehr zufrieden. Dies ist nicht die typisch-amerikanische Küche, hier kann man gut gewürzt essen und es schmeckt beinahe schon ein wenig europäisch ... was ja dann auch wieder gut zu Boston passt, der europäischsten Stadt, die wir in den ganzen Neuenglandstaaten auf unserer Rundreise erlebten.
# fr : Excellent service mais nourriture très moyenne
# Le burger au saumon est infâme! :( je ne m'attendais à rien, mais quand même
# L'endroit est très bien placé, près de la bibliothèque publique, avec une belle terrasse, au coeur de la ville, c'est spacieux, tout en longueur et la bière est bonne. Encore une fois c'est un bar plus qu'un restaurant mais c'est pas une raison pour faire n'importe quoi avec les ingrédients. Cela dit, la salade césar était bonne Comment manquer une salade césar? me direz-vous
# de : Sandwich decent. Espresso okay
# ro : Great grilled calamari.
# fr : My very favorite restaurant.
# id : chicken dang dang is amazingggggg
# ro : Great jazz, excellent service.
# so : Small hideway,, good relaxing jazz
# nl : Een van de betere Italiaanse restau's in Boston, South End is een leuke buurt
# ca : Bogus calzones. Avoid.
# it : Delicious buffalo calzone!
# fr : Terrible experience. Rude staff.
# no : All set. Never again.
# so : good yummi food
# so : Good beer, good food, good times!
# it : fabulous pizza
# ro : Instant favorite!!
# it : Best pizza in Boston.
# ca : lefty & lamb.
# tl : effing amazing.
# langdetect failed : ???
# tr : Yum, yum, yum...
# nl : Best cheese slice in JP, no doubt!
# it : their pepperoni pizza is amazing!
# id : #1 IN JP!
# it : Pineapple, garlic & green pepper pizza is pretty good!
# no : Freshest salsa ever!
# fr : quaint and fun
# no : Mmmm pretty tasty!
# es : No puedo discutir que el emparedado fuera grande. El cerdo del jamn y de carnes asadas fue tallado, usted poda todava decir por la cantidad de grasa en la carne. No es el mejor que he tenido, hecho en casa es tanto mejor con el hombro de cerdo bien sazonado, pero el servicio es bueno. Partieron la sacudida de la papaya en dos cristales ms pequeos cuando pedimos apenas uno. Los precios son muy razonables as que no pueden quejarse.
#
# Update: one of the best chicken soups I've had. It is a Hispanic version (i.e. my guess is use of sazon and adobo). Try it.
# pt : great batidos
# es : Lo mejor /the best is the picutues frames, the music, the Matelva y los camarones en salsa con una yuquita con ajo y pimientos!
# El dueno se pone pesado ...pero las chicas que sirven son bien chulas!
# get there by 11:30 or by 2pm if not ...u are out! jaja
# CubanRican!!!
# es : Primeramente empezare por decir quBal Usaae soy de Puerto Rico. Además de eso soy un cocinero aficionado. Conciente  de hay diferencias entre la cocina Cubana y la Puertoriqueña, crecí comiendo comida cubana en la isla de PR. Pedí un Asopao de camarones y Mofongo. Quede decepcionado con ambos. Una presentación muy linda pero con muy poco sabor. Los camarones sabían como si habían sido cocinados antes de la sopa , y el Mofongo con ajos de pote , no fresco. Le di 3 estrellas en vez de 2,porque no me cobraron el Mofongo porque llego después de la comida, cuando era un aperitivo. Además las meseras fueron muy atentas. Mi Señora esposa pidió un sandwich de cerdo que también estaba como decimos en PR sozo
# es : comida deliciosa con nuevos amigos
# sw : Ta bueno ya.
# af : Oops
# fr : A pompous bar requiring a dress code. puhleeeeeze.
#
# /end rant circa 2004
# ro : Poor customer experience.
# de : I LOVE THE REUBEN DOG - Russian dressing, sauerkraut, and swiss cheese. YUM!
# it : Polite servers. Good pizza. Nice prices.
# sv : OK bagels. Kupel's is better.
# fr : vegan tequila sunrise. get it.
# da : Decent standby bagel spot.
# it : great dive bar
# et : Sometimes some good jams!!!!
# af : Awesome drinks, ok food.
# nl : beer, beer, beer, beer, beer!
#
# Hooray for BEER!
# nl : Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer Beer
# so : S'good
# da : Still doing breakfast right, if not better!
# fi : I miss Dunkin Donuts man!
# sv : a black man dream
# chicken chicken and moe chicken
# damn just sum good ole chicken
# i like it all
# friggn gewd chicken
# de : Best wings in Allston!
# de : Diviest Bar Ever.
# sq : Great shizitou!!!!
# de : GROSS
# so : waaaaa!!!!! waaaaaaaa!!!!!!!
# rip!!!!!!
# i loved you!!!!!!!!!!
# nl : Delicious eggs Beni
# pt : No name, no taste.
# de : Tolle Location, mit Blick auf die Skyline von Boston. Hummer und Krabben werden einem noch lebend am Tisch zur Auswahl präsentiert. Alles ein schönes Spektakel. Aber doch eher Fastfood-mäßig. Aber bei schönem Wetter toll um mit ein paar Freunden ein Bier zu geniessen. Am Wasser mit super Aussicht.
# pt : No.
# af : Sewer water lobster tank.
# it : Giganteschi piatti di crostacei, mai visti granchi cosi grossi,  il prezzo non è certo economico ma se ci si vuol fare un regalo vale la pena. Due antipasti, un fritto ottimo e abbondante e un enorme piatto di granchi (più che sufficiente per due) piu due birre 150 dollari incluse tasse. Vale la pena di provare l esperienza,  piatti del genere in Italia e in Europa non esistono
# af : wonderful lobster.
# ja : Leagal Seafoods - Copley Place @ 米国ボストン @ シーフード
#
# ボストンの人気シーフードレストラン！
#
# 米国ボストン及び隣のハーバード大学のあるケンブリッジに複数店舗を構えるシーフードの人気店。ローガン国際空港の各ターミナルにも入って居るので、いずれかの店に行かれた方は多いと思います。
#
# ボストンのシーフードと言えばリーガルの名前が必ず上がる有名店ですが、最近まで店舗かんのクオリティーに差が有り、評価はまちまちでした。最近これが改善され、何処でも美味しいシーフードが頂けるようにとなったとの事です。
#
# シーフード全般とフィレミニオンをメインとするステーキのコンボも有り、一度に肉と魚介類を楽しむ事もできます。ただ、魚介料理の質はローカルの専門店にはやや負ける気もします。
#
# この支店は、ボストンのダウンタウン、バックベイにある一流ホテル、ショップ、レストランが立ち並ぶCopley Placeという繁華街に有ります。ここに各ホテルを結ぶ巨大なモールが有り、この一角の二階に大きな店舗を構えて居ます。
#
# 店内はバーコーナーとレストランコーナーに分かれ、窓からはボストンの古い町並みが見渡せ、良い雰囲気です。
#
# カジュアルな雰囲気の中で、ロブスター、はまぐり、海老、蟹などの魚介類を頂けます。
#
# 今日は古い友人と久々の食事を楽しみました。
#
# 私のオーダーは、
#
# 生はまぐり(チェリーストーン)半ダース
# ロブスターのビスク(カップ)
# 魚介類のグリル
#
# でした。
#
# 生のはまぐりは日本ではなかなか食べさせて貰えず、私は一度しか経験がありません。その点、ボストン、ニューヨークなどアメリカ東海岸の北部では牡蠣と共にはまぐりを楽しむ事が出来、これが楽しみです。甘みがあって、潮の香りも楽しめる蛤、私は牡蠣よりも好物なんです。
#
# ビスクは滑らかでロブスターの風味たっぷり、魚介類のグリルは、ロブスター、海老、ホタテ、鮭、鱈がたっぷり詰まって、食べた〜っという印象。
#
# 彼は名物のクラブケーキなどを頼んでいましたが、話しに熱中して写真は撮り忘れました。
#
# 親しい友との楽しいディナー、やっぱり良いですね。
#
# 100 Huntington Ave, Copley Place Mall, Boston, MA 02116, U.S.A.
#
# +1-617-266-7775
#
# 11:00-22:00
# fr : Un resto thaï sans prétention, les plats sont corrects sans plus mais deux atouts : les portions généreuses, et l'emplacement dans le délicieux quartier de Beacon Hill !
# de : Excellent French bistrot.
# fr : Best house music
# af : aweeeeeeeeeeesome drinks and service
# de : Lobster. Gnocchi.
# Enfin le moment fatidique. J'entre, je demande à être installée juste pour manger une part de cheesecake. Je prends rapidement une première photo de la vitrine. J'opte pour l'extérieur. On me donne le menu et l'on me précise que les deux dernières pages sont consacrées aux cheesecakes. Il y a un choix impressionnant. Le but du jeu étant de choisir une part pas trop lourde. J'élimine tout ce qui est à base d'Oreo, chocolat, caramel et tout ce que j'ai pu déjà goûté en France. J'aimerai une part digne de ce nom, belle comme une princesse, avec un tourbillon de crème sur le dessus, sauf qu'il n'y a pas de photos dans le menu. Je sors la photo que j'ai prise et je regarde les gâteaux qui sont bien décorés. Au jugé, en espérant ne pas me tromper, je choisis une part de key lime cheesecake. Et j'attends.
# Le gentil serveur me l'apporte :
#  (Voir photo ci-dessous)
# Première réaction : Waouh. Elle est belle ET grosse. Je pense que je ne finirai pas.
# ...
# Les prix sont habituels: au plus les sushis sont chargés et originaux, au plus les prix grimpent mais tout en restant raisonnables. J'y retournerais, et je le recommande!
# es : un sitio muy agradable, correcto, hamburguesas buenas, lo considero el típico sitio de fast food, me habían hablado mucho de él pero me pareció bastante normal, te quita el hambre pero nada más
# no : Best steak tacos ever tasted
# fr : 3 leaf clover guinness
# de : Best sandwich I've had- ever!
# so : So good!
# de : Kein aussergewöhnliches Restaurant. Man kann gemütlich sitzen, Sushi ist gut und nicht besonders teuer. Für eine kleine Pause während einer Shoppingtour auf der Newbury Street der ideale Ort um sich zu stärken!!!
# it : To go roll up special,
# ro : Great price for average dim sum.
# hr : Good standard dim sum.
# pt : Just A-Ok dim sum.
# small place.
# decent prices
# ro : Great dimsum!
# tr : very nice dim sum !!! yum !!
# so : Good bums
# tr : Yummy.
# nl : I've been here in May. Worst. Food. Ever.
# es : La comida muy salada. Lo q sobro de la bandeja paisa lo pedi para llevar y sucede q mezclaron mi comida con la de otra persona. Y sobraron dos chicharrones y solo me empacaron el q ya habia empezado a comer. Q paso con el otro? ( lo reusan para otra bandeja paisa?) . Miren bien q le empacan de lo q dejas. Puede q no sean tus frijoles. El peñol solia ser bueno , renovaron el lugar y empeoraron el servicio y comida.
# sw : No wifi?!?
# de : Das Café sieht von außen schön aus und sieht auch innen nicht schlecht aus. Leider gibt es bei genauerem hinsehen viele dreckige Stellen und Macken und dazu ist es laut und der Fernseher die ganze Zeit angeschaltet.
# Das Essen wiederum geht halbwegs. Ich aß schon besseres aber auch schlechteres.
# id : Yummy pupusas!
# de : Pub mit Guiness und Cider.
# de : Ein genialer Ort um das 4:0 für Germany zu sehen. Tolle Location, leckeres Guiness, erfrischendes Irish Cider. Die Bedienung sehr aufmerksam und schnell! Dazu absolut gute Nachos und gebackene Tintenfischringe. Yummiiii
# ro : Dive Bar Extraordinaire.
# fr : Délicieux cupcakes, il faut les essayer... Je vous conseil le red velvet. Les cupcakes sont frais et fait quotidiennement. La petite boutique est jolie et il n'y a jamais trop de monde.
# tr : Yum
# af : One word....AWFUL
# et : Real Taiwanese taste.
# it : Ghetto Chinese done average.
# es : to die for: blueberry mojitos!
# ca : Awesome, pear salad, vegetable lasagna, great service
# so : Always good!
# es : La Hacienda las peores meseras que pueden tener.
# Son unas groseras mal educadas
# Siempre que ven a un hobre que les gusten empiezan a coquetiarles
# Deberian poner mas atencion al trabajo
#
# La comida es buena pero
# Mal servicio
# ro : consistent decent food for decent price!
# da : drunken noodles ftw!
# fr : Excellent ambience with unique dishes.
# ja : This review is in Japanese,
#
# ECCO Restaurant Boston @ 米国ボストン @ ニューアメリカンクイジーヌ
#
# この雰囲気、ボストンだ！
#
# 米国ボストンのダウンタウンからすぐのLogan空港近くのダイニングバー。周りは住宅でポツンポツンとお店が有ります。通りからはボストンダウンタウンの夜景が綺麗です。
#
# ボストンに到着後幾つか電話やメールをして居たらお腹が空いて来たので、ホテルで聞いて歩いて５分程のここにやって来ました。
#
# Lobster & Corn Risotto $27 をオーダー。本当にそれだけで良いの？ パンは？ 要らない。ホントにパンは要らないの、美味しいのに、とやりとり。だって日本から着いたばかりで着陸直前に機内食を食べているんですもの。
#
# リゾットが出てびっくり、イメージと大違い。クリームスープ仕立ての、ロブスタービスクと言うべき一品。米は入って居ません。ロブスターとグリーンアスパラガスだけです。でも良い匂い。美味しい。あっ、やっぱりパンが欲しい！
#
# パンは葉巻のボックスのような木箱で登場、たっぷりのオリーブオイルにレッドペッパーが浮き美味しそう。オリーブオイルに漬けたパンも美味しいけど、リゾットにつけると更に美味しい。
#
# ウェイターに、パン美味しいねって言うと、だろ〜っ、だから勧めたんだよ！って。
#
# チェックを頼んでから、あっそうだ珈琲もお願い、OK my friend. I give it free! ですって。当然チップは20%にしましたよ。
#
# 四月下旬、まだ寒いボストンの雰囲気を堪能出来るお店でした。
#
# 107 Porter St, East Boston, MA 02128, U.S.A.
# +1-617-561-1112
# pt : nom. nom. nom.
# de : Excellent sandwiches.
# ko : 非常迷你的一間店，店內只有5個位置，但我們很幸運的有位置可以在店內享用餐點。
# 我們點了Fancy 還有 The Robbie 兩種三明治，都非常的好吃。在三明治裡有特別香料的味道，雖然有培根，但完全不油膩，味道豐富有層次。
# 新鮮的蘋果汁跟柳橙汁很真材實料。
# langdetect failed : .
# ...
# sw : amazing
# no : I like it
# langdetect failed : :)
# fr : Best bar in Boston- no contest!
# nl : Most always a good drink. No drink menu perse, just cocktails made to order. Feels like NYC.
# it : cool patio
# id : Meh.
# fr : nice recommendation!
# langdetect failed : :)
# langdetect failed : .
# nl : Smallest Chinese restaurant I've ever been in!
# sl : nice bagel..
# fresh jalapeno bagel
# so : Good food!
# af : Awesome!
# nl : Hip and happening! Best mini kobe burgers!
# de : Man kann in diesem Restaurant super essen gehen wenn man grade in der Prudential Mall war.
# Es ist von außen sehr ansprechend und auch von innen sieht es nicht schlecht aus.
# Das Personal ist sehr freundlich und entgegenkommend und das Essen und die Getränke kamen sehr schnell.
# Das Essen schmeckte sehr lecker und es gab sehr viele Saucen um das Essen zu verfeinern.
# Ein sehr gutes Lokal.
# es : Recomiendo la ensalada burrito
# es : Excellent salad choices.
# no : Only keeps getting better... love it!
# fr : PUB très agréable avec des serveurs et serveuses hyper pro.
# Nous avons passé un bon moment et le dîner était très bien.
# it : oh bella luna....just go eat the damn pizza, already.
# it : lovers lane pizza
# lovers lane pizza
# lovers lane pizza
# lovers lane pizza
# lovers lane pizza
# lovers lane pizza
# de : Wir sind beim Stadtrundgang am Freedom Trail am Ducali vorbei gekommen und fanden die Preise & Ambiente ganz ok.
# Leider mussten wir recht lange auf das Essen warten und meine Rucola Pizza kam ohne Tomatensoße unter der Beilage, was aber anscheinend normal ist?
# Der Burger mit dem englischen Muffin war ok, jedoch sehr fettig (beim Essen tropfte das Fett runter).
# Die Atmosphäre war relaxed und gut. Leider überzeugte zum Schluss die Portion gepaart mit der Qualität des Essens zum angegebenen Preis nicht.
# ro : Great menu choices
# zh-cn : 我觉得特别适合brunch！因为分量不多，可以点很多，我最爱的是流沙包！你咬一口就会爆汁出来！我经常会打包三分回家在微波炉里面一转也都特别好，其余的话那个菠萝饭也很好吃，有虾仁也不错。
# ko : 流沙包~~~！！！
# sk : ok
# hr : best soju bar, period.
# da : good for pre-flight drinks.
# de : Freezer burn.
# it : These pizzas are divine!
# no : Best vegan pizza I have ever had!!!
# no : average establishment, average food...  not very memorable.
# fr : Petite place à déjeuners qui fait penser à la fois à un café et à un restaurant. Ambiance relax, bouffe pas trop chère. J'y ai essayé les ''hashed eggs'', des oeufs avec de la viande fumée, un déjeuner typique de la région de Boston. C'était bien, les assiettes sont généreuses (une tendance évidente aux États-Unis) et on n'a aucune chance d'y mourir de faim (par contre, on se sent coupable de gaspiller, puisqu'on finit rarement un plat à moins d'avoir constamment une faim de loup).
# so : Always cool, always W.  nuf said.
# fr : exquisite morsels
# tr : Yum!!!!
# ro : Nice spot.
# af : Awesome!
# it : Non raccomando assolutamente il cappuccino...sapore pessimo! Il locale molto carino,anche se con camerieri un po' strani.
# it : Boston è una città molto fredda e quindi uscire per cena è davvero un'impresa...per questo motivo ho cercato,tramite yelp,un ristorante vicino l'albergo che potessimo raggiungere a piedi in pochi minuti. Le ottime recensioni lette ci hanno convinto a scegliere lo Stoddard's. Il locale è molto carino,arredamento in legno,ambiente caldo e accogliente; frequentato sopratutto da giovani bostioniani. Abbiamo ordinato due filetti con purè...sublimi! Carne ottima,buona scelta di birre e dolci interessanti. Da non perdere!!
# af : Great beers.
# de : Gross!
# tl : Amazing.
# pt : Pescados, pescados, eat'em up, yum!
#
# Chicken burrito, meh.
# es : El Guapo. Nuff said.
# id : Nah..
# so : so so ....wired guys
# es : Me encantó este típico restaurante americano en Boston: está en una zona muy animada, el sitio es grande, espacioso y muy bonito, no me pareció turístico y la comida excelente. También muy buen servicio. Recomiendo el Tartar de Atún, Qué bueeeno!
# zh-cn : 呵呵，来美国第一次不给小费，态度这么恶劣简直史无前例....服务员来服务的时候一脸欠他钱的样子，给毛小费啊。小费给的少还来讨...还跟我们不高兴...那小费干脆不给了好哇....价格贵，虽然材料和味道还可以。但是绝对到处宣传这种恶劣的态度！！
# ko : 服务态度简直太差！人均三十多刀贵得要死就算了，一份还少得可怜！一盘丸子只有五个！一盘冻豆腐只有五块！点五个蔬菜分量少得直接拿一个盘子就装上来了！最后还嫌小费少直接张口要！我们说你态度不值得那么多小费，老板还直接甩脸色！这种店简直就该倒闭算了！
# ca : Best mussels marinara ever!
# nl : When did everyone get younger then me?
# it : Smells like a college dive.
# fr : Pavement = ERC + Couches
# fr : Excellent place for a quick lunch
# tr : Thank you Yelp.
# it : Volcano roll is killer!
# ro : initial experience
# tl : mango sangria = crack.
# fr : Exceptional food. Unique combinations.
# ca : Awesome Guacamole! Great quesadilla! Lovely drink! My new favorite Mexican restaurant
# fr : Faint praise: great view
# it : euro. casual upscale. good drinks
# da : I've Experienced Better...
# af : Order "White Lie" drink! It is great!
# de : Burger. Try it here!!
# fr : Average restaurant.
# de : Burger. Burger.... Amazing!  enough said.  ;)
# fr : Beautiful latte art and beautiful people.
# cy : good coffee
# sl : loved it!
# tl : Great xio long bao!
# tl : Joy!
# de : Hubba Burger... DO IT!
# it : La cucina giapponese begli Usa è davvero buona quindi perchè non provarla anche a Boston? Il Q Restaurant è un locale che offre cucina giapponese, cinese e mongola di ottima qualità. Il piatto forte del locale è il Mongolian hot pot una specie di bacinella di brodo insieme alla quale portano verdure e carne cruda, che i commensali possono cuocere all'interno del brodo.... Noi da buoni italiani abbiamo evitato,anche se credo sia abbastanza buono, e abbiamo optato per sushi e carne scelta dal menu cinese. Tutto ottimo,locale da non perdere!
# so : Good!
# it : Provato solo per un drink e un paio di antipasti, tutto ottimo,  i piatti sugli altri tavoli mi sembravano spettacolari
# pl : 2 words, raw calzone.
# no : Keeps getting better...
# pt : uummm...awesome possum!
# no : Oyster sliders.. DO IT!  Lobster pasta...DON'T!
# de : Favorite restaurant in Boston.
#
# Must eat:
# Lobster Roe Noodles - best.
# Oyster Sliders -best #2
# Lobster Roll
# no : I like Neptune much better!
# da : Best fried oyster sliders evah!
# da : Ask for Doug- best bartender ever. Period.
# nl : Weeeeeeeeee!
# es : Me Gusta.  La margarita de la casa y los tacos de pescado eran las tetas!¡!¡
# langdetect failed : .
# so : Yay! I'm a fan.
# ko : 東西不錯吃 尤其是炸雞 但有點太辣
# 不過之前有午餐優惠 現在好像沒有了
# 有點可惜
# fi : SO tasty
# cy : waffles are really good!
# nl : Geweldig, echte Belgische frietjes in't midden van Boston! En lekker bier!
#
# Halfweg de toeristische toer van de stad en het regent. Wat beter dan een fris pintje en een bakje friet in een gezellig cafeetje/frituur in het midden van downtown Boston. Een absolute must maar opgepast voor spontane aanvallen van melancholie!
# nl : The Frikandel.  Just order it.
#
# You're welcome.
# fr : Les frites sont en belle fome. Style Belgique, mais on serve aussi en style québécois le potine. Délicieux et il y a un bon sélection des bières belgiques.
# langdetect failed : .
# tr : Ye
# fr : Decent restaurant. Could use more menu options!
# de : Amazing brunch!
# it : Se siete a Boston e girate pe Copley u  salto è consigliato. Locale American style birra bud e ottimi burger. Prezzo onesto
# de : Mir persönlich hat es sehr gut gefallen. Vielleicht lag es daran, dass ich dort den mit Abstand besten Vegetarischen Burger meines Lebens gegessen habe. Der - war - rich - tig - gut. Dazu gab es Pommes und einen Cesar Salat. Beides ebenfalls top. Das Ambiente war ok - das Personal sehr freundlich und zuvorkommend. Die Karte hat auch eine großartige Bier-Auswahl, die ich leider nicht testen konnte (am Mittag).
# Nicht ganz billig, aber (1) was ist in Boston schon billig (2) war es, wie gesagt wirklich lecker und damit sein Geld wert.
# ro : Chocolate Surprise Tirumisu!
# fr : L'été dernier, je suis partie en roadtrip avec mon meilleur ami et lors de notre passage à Boston, nous sommes allés dîner chez Max Brenner.
#
# L'endroit en divisé en trois partie: la terrasse ensoleillée, le restaurant intérieur et la boutique.
#
# À l'intérieur, l'ambiance est bien agréable et des tuyaux de chocolat décorent la pièce.
#
# Sur le menu, on retrouve des sandwichs, des salades, des clubs sandwichs, etc.. Rien de fancy, mais tout est bon et les portions sont immenses.
#
# Pour desserts, j'avais pris un "sunday" il était tellement gros, sucré et tellement bon que je ne pouvais pas m'arrêter de le manger même si à un moment j'ai bien cru que j'allais être malade! De la glace au chocolat, des pépites croquantes de chocolat et beurre d'arachides, des bananes, de la crème fouettée, etc... Ce dessert aurait facile pu être pour 2 à 4 personnes!
#
# Dans la boutique, on retrouve une tonne de chocolat originaux en format bonbons ou en format pépites. Il est possible de choisir les saveurs une à une ou d'acheter des sachets de pépites de différentes saveurs. Différents modèles de boîtes sont en vente. C'est la boutique parfaite pour ramener un souvenir à un de vos proches.

# %% [markdown]
# Looks like the shorter strings are being mis-categorized. Assume these are all english.

# %%
start = dt.datetime.now()
def wordlength (string):
    return len(nltk.word_tokenize(string))
reviews['length'] = reviews['text'].apply(wordlength)
print "Duration: ", dt.datetime.now() - start
# Out:
# Duration:  0:17:32.896000

# %%
reviews.loc[(reviews['length'] < 10) & (reviews['language'].isin(['zh-tw','zh-cn','ja','ko']) == False ), 'language'] = 'en'
by = reviews.groupby(['language'])
by['language'].agg(len)
# Out:
# language
# af                       11
# ca                        6
# cy                        4
# da                        8
# de                       38
# en                   228558
# es                       30
# et                        1
# fr                       40
# hr                        1
# id                        2
# it                       31
# ja                       12
# ko                        6
# langdetect failed         1
# nl                       17
# no                       10
# pt                        7
# ro                        1
# sl                        1
# so                        4
# sq                        1
# sv                        4
# tl                        2
# tr                        2
# zh-cn                     6
# zh-tw                     1
# Name: language, dtype: int64

# %% [markdown]
# we use goslate to ping google translate for translation

# %%
import goslate
import time
gs = goslate.Goslate()
gs.translate("Bon pratique, prix corrects, terrasse. Bon pour un d\xe9jeuner rapide ou \xe0 toute heure.\n\nMais on n'est pas chez Fairmont Bagel, rien \xe0 voir en qualit\xe9.",'en')
# Out:
# u'Good practice, good price, terrace. Good for one? S lunch or quick? all the time.\n\nBut it is not at Fairmont Bagel, nothing? see quality ?.'

# %%
translate_list = []
reviews['translate'] = ''

for i in reviews.loc[reviews['language'] != 'en','text']: # where language is not english, take the text,
    translate_list.append([detect(i), gs.detect(i), i]) # prep array for comparison
    reviews.loc[reviews['text'] == i,'translate'] = gs.translate(i,'en') # translate
    time.sleep(1) # we dont want to ping too quickly
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-88-f59a692e6c58> in <module>()
#       2 reviews['translate'] = ''
#       3 for i in reviews.loc[reviews['language'] != 'en','text']:
# ----> 4     translate_list.append([detect(i), gs.detect(i), i])
#       5     reviews.loc[reviews['text'] == i,'translate'] = gs.translate(i,'en')
#       6     time.sleep(1)
#
# c:\Anaconda\lib\site-packages\goslate.pyc in detect(self, text)
#     482         if _is_sequence(text):
#     483             return self._execute(functools.partial(self._detect_language, i) for i in text)
# --> 484         return self._detect_language(text)
#     485
#     486
#
# c:\Anaconda\lib\site-packages\goslate.pyc in _detect_language(self, text)
#     446         if _is_bytes(text):
#     447             text = text.decode('utf-8')
# --> 448         return self._basic_translate(text[:50].encode('utf-8'), 'en', 'auto')[1]
#     449
#     450
#
# c:\Anaconda\lib\site-packages\goslate.pyc in _basic_translate(self, text, target_language, source_language)
#     249             url += '&dt=rm'
#     250
# --> 251         response_content = self._open_url(url)
#     252         raw_data = json.loads(_empty_comma.subn('', response_content)[0].replace(u'\xA0', u' ').replace('[,', '[1,'))
#     253         data = {'src': raw_data[-1][0][0]}
#
# c:\Anaconda\lib\site-packages\goslate.pyc in _open_url(self, url)
#     179         for i in range(self._RETRY_TIMES):
#     180             try:
# --> 181                 response = self._opener.open(request, timeout=self._TIMEOUT)
#     182                 response_content = response.read().decode('utf-8')
#     183                 if self._DEBUG:
#
# c:\Anaconda\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     402             req = meth(req)
#     403
# --> 404         response = self._open(req, data)
#     405
#     406         # post-process response
#
# c:\Anaconda\lib\urllib2.pyc in _open(self, req, data)
#     420         protocol = req.get_type()
#     421         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 422                                   '_open', req)
#     423         if result:
#     424             return result
#
# c:\Anaconda\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     380             func = getattr(handler, meth_name)
#     381
# --> 382             result = func(*args)
#     383             if result is not None:
#     384                 return result
#
# c:\Anaconda\lib\urllib2.pyc in http_open(self, req)
#    1212
#    1213     def http_open(self, req):
# -> 1214         return self.do_open(httplib.HTTPConnection, req)
#    1215
#    1216     http_request = AbstractHTTPHandler.do_request_
#
# c:\Anaconda\lib\urllib2.pyc in do_open(self, http_class, req)
#    1182         except socket.error, err: # XXX what error?
#    1183             h.close()
# -> 1184             raise URLError(err)
#    1185         else:
#    1186             try:
#
# URLError: <urlopen error timed out>

# %%
translate_list

# %%
reviews.loc[reviews['translate'] != "", ['text','translate']].head(10)

# %%
reviews.to_pickle('data/intermediate/translate.pkl') # pickle results in case we need to revert back to them
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-83130038153b> in <module>()
# ----> 1 reviews.to_pickle('data/intermediate/translate.pkl') # pickle results in case we need to revert back to them
#
# NameError: name 'reviews' is not defined

# %% [markdown]
# Combine translated reviews and other text

# %%
reviews = pd.read_pickle('data/intermediate/translate.pkl')
reviews.loc[reviews['translate'] != '','final_text'] = reviews['translate'] # if translate is not missing, then use translate
reviews.loc[reviews['translate'] == '','final_text'] = reviews['text'] # if translate is missing, then use original text

# some assertions
assert((max(reviews['final_text'] == '') == False) == True) # no missing reviews
assert((max(reviews['final_text'].isnull()) == False) == True) # no NaN reviews

# %% [markdown]
# Process Text

# %%
# make same capitalization
reviews['final_text']=reviews['final_text'].str.lower()
reviews.to_pickle('data/intermediate/pre_process.pkl') # pickle results in case we need to revert back to them

# %%
# remove punctuation, stopwords, lemmatize
# make ngrams (potentially want to experiment with multiple ngrams (up to quadgrams?))

import nltk
from nltk.util import ngrams

wnl = nltk.WordNetLemmatizer()

def ngramfunc(string,gram_count):
    
    # remove punctuations
    string = ''.join(ch for ch in string if ch not in punctuations) 
    
    # not fancy list comprehension here to avoid lemmatizing twice or running over the list twice
    string_array = []
    for word in string.split():
        lemmatized = wnl.lemmatize(word) # lemmatize the word
        if lemmatized not in stopwords:
            string_array.append(lemmatized) # if lemmatized word not in stop words, add to string array
        else:
            pass
    
    # place into ngrams
    gram_array = []
    for i in ngrams(string_array,gram_count):
        gram_array.append(i)
    return gram_array

# %%
# testing
reviews['final_text'][:5].apply(lambda string,gramcount: ngramfunc(string,gramcount), args=(2,))
# Out:
# 0    [(pretty, typical), (typical, cafe), (cafe, sa...
# 1    [(agree, reviewer), (reviewer, pretty), (prett...
# 2    [(decent, enough), (enough, food), (food, over...
# 3    [(muffin, greatesp), (greatesp, blueberry), (b...
# 4    [(well, well), (well, well), (well, look), (lo...
# Name: final_text, dtype: object

# %% [markdown]
# We write a script that can be called from a batch file to run this asynchronously

# %%
script = '''
import pandas as pd
import sys
import nltk
from nltk.util import ngrams
import string
punctuations = set(string.punctuation)
from nltk.corpus import stopwords
stopwords = stopwords.words('english') # replace the stop word list

ngramcount = sys.argv[1]
varname = 'ngrams' + ngramcount
wnl = nltk.WordNetLemmatizer()

def ngramfunc(string,gram_count):
    
    # remove punctuations
    string = ''.join(ch for ch in string if ch not in punctuations) 
    
    # not fancy list comprehension here to avoid lemmatizing twice or running over the list twice
    string_array = []
    for word in string.split():
        lemmatized = wnl.lemmatize(word) # lemmatize the word
        if lemmatized not in stopwords:
            string_array.append(lemmatized) # if lemmatized word not in stop words, add to string array
        else:
            pass
    
    # place into ngrams
    gram_array = []
    for i in ngrams(string_array,gram_count):
        gram_array.append(i)
    return gram_array
    
df = pd.read_pickle('data/intermediate/pre_process.pkl')
df = df.loc[:,['restaurant_id','date','final_text']]
print "running ngrams ",ngramcount
df[varname] = df['final_text'].apply(lambda string,gramcount: ngramfunc(string,gramcount), args=(int(ngramcount),))
df.to_pickle('data/intermediate/ngrams' + ngramcount + '.pkl')
'''
filepath = open("ngram.py",'w')
filepath.writelines(script)
filepath.close()

# %%
bat = '''
start python ngram.py 1
start python ngram.py 2
start python ngram.py 3
start python ngram.py 4
'''
filepath = open("exec.bat",'w')
filepath.writelines(bat)
filepath.close()

# %%
subprocess.call('exec.bat')
def watcher():
    flag = 0
    while True:
        arraylist = os.listdir('data/intermediate')
        if ('ngrams1.pkl' in arraylist) & ('ngrams2.pkl' in arraylist) & ('ngrams3.pkl' in arraylist) & ('ngrams4.pkl' in arraylist):
            return
watcher()
print "files done"
print "deleting files"
os.remove("exec.bat")
os.remove("ngram.py")
